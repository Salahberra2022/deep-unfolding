# %%
"""This module contains the core functions."""
import numpy as np
import torch
import matplotlib.pyplot as plt

from methods import itr_list, norm_list_GS, norm_list_RI, norm_list_Jacobi, norm_list_SOR, norm_list_AOR, norm_list_AOR_CHEBY, norm_list_SOR_CHEBY

from constants import *
# Out:
# Condition number, min. and max. eigenvalues of A:
# 30.828752475024576 5.678370598467175 0.18419073567986302
# Condition number, min. and max. eigenvalues of A:
# 30.828752475024576 5.678370598467175 0.18419073567986302
# generation: 1  batch: 0 	 MSE loss: 0.2129644751548767
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 8>()
#       4 import matplotlib.pyplot as plt
#       6 from methods import itr_list, norm_list_GS, norm_list_RI, norm_list_Jacobi, norm_list_SOR, norm_list_AOR, norm_list_AOR_CHEBY, norm_list_SOR_CHEBY
# ----> 8 from constants import *
#
# File c:\Users\dell\Desktop\deep_unfolding\deep_unfolding\constants.py:4, in <module>
#       1 # Script to englobe all constants used in the different scripts
#       3 from methods import norm_list_GS, norm_list_RI, norm_list_Jacobi, norm_list_SOR, norm_list_AOR, norm_list_AOR_CHEBY, norm_list_SOR_CHEBY
# ----> 4 from train_methods import norm_list_SorNet, norm_list_Sor_Cheby_Net, norm_list_AorNet, norm_list_rinet
#       6 methods_dict = {
#       7     "GS" : norm_list_GS,
#       8     "RI" : norm_list_RI,
#    (...)
#      17     'RINet' : norm_list_rinet
#      18 }
#      20 # for visualization
#
# File c:\Users\dell\Desktop\deep_unfolding\deep_unfolding\train_methods.py:283, in <module>
#     281 for i in range(num_batch):
#     282     opt1.zero_grad()
# --> 283     solution = torch.normal(0.0 * torch.ones(bs, n), 1.0).to(device)
#     284     y = solution @ H
#     285     x_hat, _ = model_SorNet(gen + 1, bs, y)
#
# KeyboardInterrupt:

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu") # GPU, if not CPU
print(f"Code run on : {device}")

# Name and model correspondance for use
methods_dict = {
    "GS" : norm_list_GS,
    "RI" : norm_list_RI, 
    "Jacobi" : norm_list_Jacobi,
    "SOR" : norm_list_SOR,
    "ChebySOR" : norm_list_SOR_CHEBY,
    "AOR" : norm_list_AOR,
    "ChebyAOR" : norm_list_AOR_CHEBY
}

# for visualization
marker_list = ['^k-', 'sb-', 'og-', 'Xc-', 'hk-', 'sk-', '^c-', 'sr-', '^r:', '^b:', 'ok:', 'sg:', '^y:']

def main(list_iterative):
    """Plot the MSE for different iterative methods.

    Args:
        list_iterative (list): List of iterative methods.

    """

    norm_list = np.zeros((len(list_iterative), len(itr_list)))

    for k, iterative in enumerate(list_iterative):
        norm_list[k] = methods_dict[iterative]

    # visualization
    for k, iterative in enumerate(list_iterative):
        plt.semilogy(itr_list, norm_list[k], marker_list[k], label=iterative)

    plt.xlabel('iterations')
    plt.ylabel('MSE')
    plt.yscale('log')
    plt.legend()
    plt.show()
# Out:
# Code run on : cpu

# %%
list_iterative=['RI', 'SOR', 'GS']

main(list_iterative)
